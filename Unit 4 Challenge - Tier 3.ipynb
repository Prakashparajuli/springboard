# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
# Load the pyplot collection of functions from matplotlib, as plt 



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

#url= "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
#properties = pd._ _ _(url_LondonHousePrices, sheet_name='Average price', index_col= None)




url= "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"
properties=pd.read_excel(url,sheet_name='Average price', index_col=None)
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.set_index('Unnamed: 0',inplace=True)
properties.index
# Out:
# DatetimeIndex([       'NaT', '1995-01-01', '1995-02-01', '1995-03-01',
#                '1995-04-01', '1995-05-01', '1995-06-01', '1995-07-01',
#                '1995-08-01', '1995-09-01',
#                ...
#                '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01',
#                '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01'],
#               dtype='datetime64[ns]', name='Unnamed: 0', length=304, freq=None)

# %%
properties.drop(properties.index[0],inplace=True) #This row is a duplicate information for name of borough, Hence I droped it. 
properties.head()
# Out:
#            City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# Unnamed: 0
# 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
#             Bromley  Camden  Croydon   Ealing  Enfield  ... NORTH WEST  \
# Unnamed: 0                                              ...
# 1995-01-01  81671.5  120933  69158.2  79885.9  72514.7  ...    43958.5
# 1995-02-01  81657.6  119509  68951.1  80897.1  73155.2  ...    43925.4
# 1995-03-01  81449.3  120282  68712.4  81379.9  72190.4  ...    44434.9
# 1995-04-01  81124.4  120098    68610  82188.9  71442.9  ...    44267.8
# 1995-05-01  81542.6  119929  68844.9  82077.1  70630.8  ...    44223.6
#
# ...

# %%
properties.index.name='Date'
properties.columns.name='Borough'
properties.head()
# Out:
# Borough    City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# Date
# 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
# Borough     Bromley  Camden  Croydon   Ealing  Enfield  ... NORTH WEST  \
# Date                                                    ...
# 1995-01-01  81671.5  120933  69158.2  79885.9  72514.7  ...    43958.5
# 1995-02-01  81657.6  119509  68951.1  80897.1  73155.2  ...    43925.4
# 1995-03-01  81449.3  120282  68712.4  81379.9  72190.4  ...    44434.9
# 1995-04-01  81124.4  120098    68610  82188.9  71442.9  ...    44267.8
# 1995-05-01  81542.6  119929  68844.9  82077.1  70630.8  ...    44223.6
#
# ...

# %%
properties.columns=properties.columns.str.title()
properties.columns
# Out:
# Index(['City Of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston Upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond Upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Unnamed: 34', 'Inner London', 'Outer London', 'Unnamed: 37',
#        'North East', 'North West', 'Yorks & The Humber', 'East Midlands',
#        'West Midlands', 'East Of England', 'London', 'South East',
#        'South West', 'Unnamed: 47', 'England'],
#       dtype='object', name='Borough')

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %%
properties.head()
# Out:
# Borough    City Of London Barking & Dagenham   Barnet   Bexley    Brent  \
# Date
# 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
# Borough     Bromley  Camden  Croydon   Ealing  Enfield  ... North West  \
# Date                                                    ...
# 1995-01-01  81671.5  120933  69158.2  79885.9  72514.7  ...    43958.5
# 1995-02-01  81657.6  119509  68951.1  80897.1  73155.2  ...    43925.4
# 1995-03-01  81449.3  120282  68712.4  81379.9  72190.4  ...    44434.9
# 1995-04-01  81124.4  120098    68610  82188.9  71442.9  ...    44267.8
# 1995-05-01  81542.6  119929  68844.9  82077.1  70630.8  ...    44223.6
#
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 303 entries, 1995-01-01 to 2020-03-01
# Data columns (total 48 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City Of London        303 non-null    object
#  1   Barking & Dagenham    303 non-null    object
#  2   Barnet                303 non-null    object
#  3   Bexley                303 non-null    object
#  4   Brent                 303 non-null    object
#  5   Bromley               303 non-null    object
#  6   Camden                303 non-null    object
#  7   Croydon               303 non-null    object
#  8   Ealing                303 non-null    object
#  9   Enfield               303 non-null    object
#  10  Greenwich             303 non-null    object
#  11  Hackney               303 non-null    object
#  12  Hammersmith & Fulham  303 non-null    object
#  13  Haringey              303 non-null    object
# ...

# %%
properties.drop(['Unnamed: 34','Unnamed: 37','Unnamed: 47'], axis=1,inplace=True)# dropped null columns

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties=properties.apply(pd.to_numeric)
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 303 entries, 1995-01-01 to 2020-03-01
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City Of London        303 non-null    float64
#  1   Barking & Dagenham    303 non-null    float64
#  2   Barnet                303 non-null    float64
#  3   Bexley                303 non-null    float64
#  4   Brent                 303 non-null    float64
#  5   Bromley               303 non-null    float64
#  6   Camden                303 non-null    float64
#  7   Croydon               303 non-null    float64
#  8   Ealing                303 non-null    float64
#  9   Enfield               303 non-null    float64
#  10  Greenwich             303 non-null    float64
#  11  Hackney               303 non-null    float64
#  12  Hammersmith & Fulham  303 non-null    float64
#  13  Haringey              303 non-null    float64
# ...

# %%
properties.describe().T
# Out:
#                       count           mean            std           min  \
# Borough
# City Of London        303.0  426591.293975  243309.605693   77101.20804
# Barking & Dagenham    303.0  160866.762697   77158.176037   50460.22660
# Barnet                303.0  306455.437541  142117.801134   90107.23471
# Bexley                303.0  190501.366135   85925.728065   63722.70055
# Brent                 303.0  271605.422138  134692.643998   71306.56698
# Bromley               303.0  255289.152870  113506.304485   81124.41227
# Camden                303.0  470173.515540  242795.595397  115418.83960
# Croydon               303.0  210391.517241   94183.966427   68006.00735
# Ealing                303.0  275760.889754  128926.947924   79272.34618
# Enfield               303.0  224707.872657  102506.301990   70630.77955
# Greenwich             303.0  214419.298108  104966.670244   60993.26863
# Hackney               303.0  287648.487454  162774.658338   61296.52637
# ...

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties=properties.reset_index()
properties.head()
# Out:
# Borough       Date  City Of London  Barking & Dagenham       Barnet  \
# 0       1995-01-01     91448.98487         50460.22660  93284.51832
# 1       1995-02-01     82202.77314         51085.77983  93190.16963
# 2       1995-03-01     79120.70256         51268.96956  92247.52435
# 3       1995-04-01     77101.20804         53133.50526  90762.87492
# 4       1995-05-01     84409.14932         53042.24852  90258.00033
#
# Borough       Bexley        Brent      Bromley       Camden      Croydon  \
# 0        64958.09036  71306.56698  81671.47692  120932.8881  69158.16225
# 1        64787.92069  72022.26197  81657.55944  119508.8622  68951.09542
# 2        64367.49344  72015.76274  81449.31143  120282.2131  68712.44341
# 3        64277.66881  72965.63094  81124.41227  120097.8990  68610.04641
# 4        63997.13588  73704.04743  81542.61561  119929.2782  68844.91690
#
# Borough       Ealing  ...   North East   North West  Yorks & The Humber  \
# ...

# %%
properties['Date']
# Out:
# 0     1995-01-01
# 1     1995-02-01
# 2     1995-03-01
# 3     1995-04-01
# 4     1995-05-01
#          ...
# 298   2019-11-01
# 299   2019-12-01
# 300   2020-01-01
# 301   2020-02-01
# 302   2020-03-01
# Name: Date, Length: 303, dtype: datetime64[ns]

# %%
properties['year']=properties['Date'].apply(lambda date:date.year)

# %%
properties.head()
# Out:
# Borough       Date  City Of London  Barking & Dagenham       Barnet  \
# 0       1995-01-01     91448.98487         50460.22660  93284.51832
# 1       1995-02-01     82202.77314         51085.77983  93190.16963
# 2       1995-03-01     79120.70256         51268.96956  92247.52435
# 3       1995-04-01     77101.20804         53133.50526  90762.87492
# 4       1995-05-01     84409.14932         53042.24852  90258.00033
#
# Borough       Bexley        Brent      Bromley       Camden      Croydon  \
# 0        64958.09036  71306.56698  81671.47692  120932.8881  69158.16225
# 1        64787.92069  72022.26197  81657.55944  119508.8622  68951.09542
# 2        64367.49344  72015.76274  81449.31143  120282.2131  68712.44341
# 3        64277.66881  72965.63094  81124.41227  120097.8990  68610.04641
# 4        63997.13588  73704.04743  81542.61561  119929.2782  68844.91690
#
# Borough       Ealing  ...   North West  Yorks & The Humber  East Midlands  \
# ...

# %%
columns=properties.columns
columns
# Out:
# Index(['Date', 'City Of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston Upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond Upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Inner London', 'Outer London', 'North East',
#        'North West', 'Yorks & The Humber', 'East Midlands', 'West Midlands',
#        'East Of England', 'London', 'South East', 'South West', 'England',
#        'year'],
#       dtype='object', name='Borough')

# %%
no_boroughs=['City Of London', 'Date', 'East Midlands', 'East Of England', 'England','Inner London','London','North East','North West','Outer London','South East','South West','West Midlands','Yorks & The Humber']

# %%
len(columns)-len(no_boroughs)
# Out:
# 33

# %%
properties=properties.drop(no_boroughs,axis=1)
properties.columns
# Out:
# Index(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden',
#        'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon',
#        'Hounslow', 'Islington', 'Kensington & Chelsea', 'Kingston Upon Thames',
#        'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond Upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'year'],
#       dtype='object', name='Borough')

# %%
avgPrice_year=properties.groupby('year').mean()# average price by year 
avgPrice_year
# Out:
# Borough  Barking & Dagenham         Barnet         Bexley          Brent  \
# year
# 1995           51817.969390   91792.537433   64291.532845   73029.841840
# 1996           51718.192690   94000.445448   65490.417234   75235.918367
# 1997           55974.262309  106883.185546   70789.406603   86749.070663
# 1998           60285.821083  122359.468033   80632.020822  100692.590417
# 1999           65320.934441  136004.512067   86777.715903  112157.469808
# 2000           77549.513290  167952.633958  103186.665184  140962.500458
# 2001           88664.058223  185563.352600  116527.134750  157287.404625
# 2002          112221.912482  220746.059225  136797.964475  185898.147992
# 2003          142498.927800  251212.927683  164482.038908  216501.757008
# 2004          158175.982483  271854.112992  179141.168258  236023.435958
# 2005          163360.782017  279459.669683  186512.186267  241690.070950
# 2006          167853.342558  291337.796208  191831.056892  253253.437858
# ...

# %%
avgPrice_year.loc[2020,:].sort_values(ascending=False).head(10)
# Out:
# Borough
# Kensington & Chelsea    1.315151e+06
# Westminster             1.043060e+06
# Camden                  8.388534e+05
# Hammersmith & Fulham    7.479047e+05
# Islington               6.596961e+05
# Richmond Upon Thames    6.535579e+05
# Wandsworth              6.121221e+05
# Hackney                 5.917446e+05
# Haringey                5.594189e+05
# Lambeth                 5.276388e+05
# Name: 2020, dtype: float64

# %%
avgPrice_year.loc[2018,:].sort_values(ascending=False).head(10)
# Out:
# Borough
# Kensington & Chelsea    1.363880e+06
# Westminster             1.020025e+06
# Camden                  8.424104e+05
# Hammersmith & Fulham    7.255253e+05
# Richmond Upon Thames    6.526654e+05
# Islington               6.498241e+05
# Wandsworth              5.966491e+05
# Haringey                5.515606e+05
# Hackney                 5.446405e+05
# Barnet                  5.332665e+05
# Name: 2018, dtype: float64

# %%
avgPrice_year.loc[2019,:].sort_values(ascending=False).head(10)
# Out:
# Borough
# Kensington & Chelsea    1.243722e+06
# Westminster             9.553525e+05
# Camden                  8.417444e+05
# Hammersmith & Fulham    7.214588e+05
# Richmond Upon Thames    6.500275e+05
# Islington               6.346101e+05
# Wandsworth              5.886131e+05
# Hackney                 5.556550e+05
# Haringey                5.472222e+05
# Barnet                  5.196113e+05
# Name: 2019, dtype: float64

# %%
avgPrice_year.loc[1998,:].sort_values(ascending=False).head(10)
# Out:
# Borough
# Kensington & Chelsea    268350.122142
# Westminster             190531.949942
# Hammersmith & Fulham    175340.921250
# Camden                  170688.973933
# Richmond Upon Thames    162956.066025
# Islington               134148.973300
# Wandsworth              125406.807233
# Barnet                  122359.468033
# Kingston Upon Thames    116399.769158
# Harrow                  114778.250067
# Name: 1998, dtype: float64

# %%
avgPrice_year.reset_index().plot(x='year',y=['Kensington & Chelsea','Barking & Dagenham','Barnet', 'Westminster'], kind='line', figsize=(12,8))
plt.ylabel('average_price')
# Out:
# Text(0, 0.5, 'average_price')

# %%
price_ratio_1998_18=(avgPrice_year.loc[2018]/avgPrice_year.loc[1998]).sort_values(ascending=False)
price_ratio_1998_18=price_ratio_1998_18.to_frame().reset_index().rename(columns={'Borough':'Borough',0:'price_ratio_1998_2018'})
price_ratio_1998_18.head()
# Out:
#           Borough  price_ratio_1998_2018
# 0         Hackney               6.198286
# 1  Waltham Forest               5.834756
# 2       Southwark               5.516485
# 3        Lewisham               5.449221
# 4     Westminster               5.353565

# %%
avgPrice_year.loc[[1998,2018],'Hackney']
# Out:
# year
# 1998     87869.535804
# 2018    544640.475027
# Name: Hackney, dtype: float64

# %%
ax=price_ratio_1998_18.plot(x='Borough',kind='bar', figsize=(10,6))
ax.set_ylabel('averagePrice_ratio')
# Out:
# Text(0, 0.5, 'averagePrice_ratio')

# %%
top5=['Hackney', 'Waltham Forest', 'Southwark', 'Lewisham','Westminster']
avgPrice_year.reset_index().plot(x='year',y=top5, kind='line', figsize=(12,8))
plt.ylabel('average_price')
# Out:
# Text(0, 0.5, 'average_price')

# %%
price_ratio_1998_18.head()
# Out:
#           Borough  price_ratio_1998_2018
# 0         Hackney               6.198286
# 1  Waltham Forest               5.834756
# 2       Southwark               5.516485
# 3        Lewisham               5.449221
# 4     Westminster               5.353565

# %%
price_ratio_1995_20=(avgPrice_year.loc[2020]/avgPrice_year.loc[1995]).sort_values(ascending=False)
price_ratio_1995_20=price_ratio_1995_20.to_frame().reset_index().rename(columns={'Borough':'Borough',0:'price_ratio_1995_2020'})
price_ratio_1995_20.head()
# Out:
#          Borough  price_ratio_1995_2020
# 0        Hackney               8.962504
# 1    Westminster               7.802126
# 2        Lambeth               7.747352
# 3      Southwark               7.744833
# 4  Tower Hamlets               7.388082

# %%
price_ratio_2010_20=(avgPrice_year.loc[2020]/avgPrice_year.loc[2010]).sort_values(ascending=False)
price_ratio_2010_20=price_ratio_2010_20.to_frame().reset_index().rename(columns={'Borough':'Borough',0:'price_ratio_2010_2020'})
price_ratio_2010_20.head()
# Out:
#               Borough  price_ratio_2010_2020
# 0      Waltham Forest               1.982544
# 1             Hackney               1.969260
# 2  Barking & Dagenham               1.873276
# 3              Newham               1.846974
# 4            Lewisham               1.841999

# %%
price_ratio_2019_20=(avgPrice_year.loc[2020]/avgPrice_year.loc[2019]).sort_values(ascending=False)
price_ratio_2019_20=price_ratio_2019_20.to_frame().reset_index().rename(columns={'Borough':'Borough',0:'price_ratio_2019_2020'})
price_ratio_2019_20.head()
# Out:
#                 Borough  price_ratio_2019_2020
# 0           Westminster               1.091807
# 1         Tower Hamlets               1.072546
# 2               Hackney               1.064950
# 3  Kensington & Chelsea               1.057431
# 4    Barking & Dagenham               1.044853

# %% [markdown]
# ## Top 10 Borough with high price increase

# %%
top_10=pd.concat([price_ratio_1998_18['Borough'],price_ratio_1995_20['Borough'],price_ratio_2010_20['Borough'],price_ratio_2019_20['Borough']],axis=1)
top_10.columns=['Borough_1998_18','Borough_1995_20','Borough_2010_20','Borough_2019_20']
top_10.head(10)
# Out:
#         Borough_1998_18 Borough_1995_20     Borough_2010_20  \
# 0               Hackney         Hackney      Waltham Forest
# 1        Waltham Forest     Westminster             Hackney
# 2             Southwark         Lambeth  Barking & Dagenham
# 3              Lewisham       Southwark              Newham
# 4           Westminster   Tower Hamlets            Lewisham
# 5                Newham  Waltham Forest            Haringey
# 6              Haringey        Lewisham             Lambeth
# 7  Kensington & Chelsea        Haringey           Greenwich
# 8               Lambeth          Camden         Westminster
# 9                Camden          Newham           Southwark
#
#         Borough_2019_20
# 0           Westminster
# 1         Tower Hamlets
# 2               Hackney
# 3  Kensington & Chelsea
# 4    Barking & Dagenham
# 5            Wandsworth
# 6             Islington
# 7               Lambeth
# 8                Newham
# 9  Hammersmith & Fulham

# %% [markdown]
# ### Conclusion
# Based on 1998 and 2018, **Hackney** shows a highest increase in average price. However, looking over the trend of recent increase in price other boroughs like **Westminister, Waltham Forest and Barking & Dagenham** also shows higher increase in addition to Hackney.
#
# Interstingly, the average increase in price of Hackney which is in the list of top two shows low increase in 2020 compared to 2019.
#
# Despite having highest increase in average price of Hackney borough, **Kensington & Chelsea** borough remains the most expensive borough.
